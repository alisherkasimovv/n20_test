# %% [markdown]
# <a href="https://colab.research.google.com/github/alisherkasimovv/n20_test/blob/main/transposing_swapping_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
A_array = np.arange(6).reshape(3,2)

# %%
A_array
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
A_array.T
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
A_array.swapaxes(0,1)
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
np.dot(A_array, A_array.T)
# Out:
# array([[ 1,  3,  5],
#        [ 3, 13, 23],
#        [ 5, 23, 41]])

# %% [markdown]
# #FUNCTIONS
#
# - UNARY AND BINARY BUILT IN FUNCTIONS IN NUMPY LIBRARY

# %%
arr = np.arange(10)

# %%
np.sqrt(arr)
# Out:
# array([0.        , 1.        , 1.41421356, 1.73205081, 2.        ,
#        2.23606798, 2.44948974, 2.64575131, 2.82842712, 3.        ])

# %%
np.square(arr)
# Out:
# array([ 0,  1,  4,  9, 16, 25, 36, 49, 64, 81])

# %%
np.log(arr)
# Out:
# <ipython-input-15-a67b4ae04e95>:1: RuntimeWarning: divide by zero encountered in log
#   np.log(arr)
# array([      -inf, 0.        , 0.69314718, 1.09861229, 1.38629436,
#        1.60943791, 1.79175947, 1.94591015, 2.07944154, 2.19722458])

# %%
np.exp(arr)
# Out:
# array([1.00000000e+00, 2.71828183e+00, 7.38905610e+00, 2.00855369e+01,
#        5.45981500e+01, 1.48413159e+02, 4.03428793e+02, 1.09663316e+03,
#        2.98095799e+03, 8.10308393e+03])

# %%
arr1 = np.random.randn(6)

# %%
arr1
# Out:
# array([ 0.73083317, -0.83926104,  0.46575191,  0.73727369,  0.03305331,
#         1.40000667])

# %%
integer , remainder = np.modf(arr1)

# %%
integer
# Out:
# array([ 0.73083317, -0.83926104,  0.46575191,  0.73727369,  0.03305331,
#         0.40000667])

# %%
remainder
# Out:
# array([ 0., -0.,  0.,  0.,  0.,  1.])

# %%
np.sign(arr)
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 1, 1])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.isnan(arr1)
# Out:
# array([False, False, False, False, False, False])

# %%
arr1[0] = np.NaN

# %%
np.isnan(arr1)
# Out:
# array([ True, False, False, False, False, False])

# %%
arr1
# Out:
# array([        nan, -0.83926104,  0.46575191,  0.73727369,  0.03305331,
#         1.40000667])
